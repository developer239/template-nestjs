# %% [markdown]
# # Setup Flow
#
# This notebook guides you through the setup flow of a new project.

# %% [markdown]
# ### Variables
# Set project environment. Default environment is `dev`.

# %%
env = "dev"
bucket_name = "api-terraform-state-dev"

# %% [markdown]
# Define basic project values.

# %%
project_id = "template-nestjs-api"
project_name = "BE Template API"

# %% [markdown]
# Define project secrets.

# %%
jwt_secret_value = "some-jwt-secret"
db_username = "some-db-user"
db_password = "some-db-password"

# %% [markdown]
# Define other variables.

# %%
region = "us-central1"
docker_image_name = "app-service"
db_tier = "db-f1-micro"

# %% [markdown]
# Create `tfvars` file for the `environments` folder.

# %%
import os

# Path to the terraform.tfvars file
tfvars_file_path = f"environments/{env}/terraform.tfvars"

# Check if the file exists
if os.path.isfile(tfvars_file_path):
  # If the file exists, delete it
  os.remove(tfvars_file_path)
  print(f"Existing terraform.tfvars file deleted: {tfvars_file_path}")

# Variables for the terraform.tfvars file content
terraform_tfvars_content = f"""environment = "{env}"
project_id = "{project_id}"
region = "{region}"

# App
app_api_prefix = "api"
app_api_name = "{project_name} [{env}]"
app_api_auth_jwt_token_expires_in = "1d"

# Database
database_name = "api_db"
db_tier= "{db_tier}"
"""

# Write content to the terraform.tfvars file
with open(tfvars_file_path, "w") as f:
  f.write(terraform_tfvars_content)

print(f"terraform.tfvars file created at: {tfvars_file_path}")
# Out:
# Existing terraform.tfvars file deleted: environments/dev/terraform.tfvars
# terraform.tfvars file created at: environments/dev/terraform.tfvars

# %% [markdown]
# ## Change CHDIR

# %% [markdown]
# We need to change the current working directory to the `environments/{env}` folder so that terraform commands can be executed in the correct directory.

# %%
import os
os.chdir(f"./environments/{env}")
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/michaljarnot/IdeaProjects/backend-template-nestjs-api-5/infra/environments/dev

# %% [markdown]
# ## Google Cloud Project Setup

# %%
# Authenticate with Google Cloud
# !gcloud auth login
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=bk91M77u6ZFxrpqTvP2bHaEbdTvrJH&access_type=offline&code_challenge=WbIVVzy63dpFzmjOO0ChJl6RARhQdocO8Czb-wbY7Ag&code_challenge_method=S256
#
#
# You are now logged in as [m.jarnot@yahoo.com].
# Your current project is [some-project-id-546757].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID
#
#
# Updates are available for some Google Cloud CLI components.  To install them,
# please run:
#   $ gcloud components update

# %%
# Create a new Google Cloud project
# !gcloud projects create {project_id} --name="{project_name}"
# Out:
# Create in progress for [https://cloudresourcemanager.googleapis.com/v1/projects/template-nestjs-api].
# Waiting for [operations/cp.8786503144929325054] to finish...done.
# Enabling service [cloudapis.googleapis.com] on project [template-nestjs-api]...
# Operation "operations/acat.p2-812254980684-71f75b6d-6268-4327-a351-6735ca6a09c5" finished successfully.

# %%
# Set your Google Cloud project
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# Set the default region and zone for your project
# !gcloud auth application-default login
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=icJlWLZn8tbArzWU0RbE3hOPnOIZBe&access_type=offline&code_challenge=Xug4iIwabi_PhAeJw_LtmnIRYoZMegDqLBm3jSVcZs0&code_challenge_method=S256
#
#
# Credentials saved to file: [/Users/michaljarnot/.config/gcloud/application_default_credentials.json]
#
# These credentials will be used by any library that requests Application Default Credentials (ADC).
#
# Quota project "template-nestjs-api" was added to ADC which can be used by Google client libraries for billing and quota. Note that some services may still bill the project owning the resource.

# %% [markdown]
# ## Required Google Cloud Services
# Link billing account to your project.

# %%
import webbrowser
billing_account_link = "https://console.cloud.google.com/billing/linkedaccount?hl=en&project=" + project_id
webbrowser.open(billing_account_link)
# Out:
# True

# %%
# !gcloud services enable artifactregistry.googleapis.com compute.googleapis.com cloudbuild.googleapis.com secretmanager.googleapis.com sqladmin.googleapis.com storage.googleapis.com iam.googleapis.com cloudresourcemanager.googleapis.com run.googleapis.com
# Out:
# Operation "operations/acf.p2-812254980684-e9c4c75f-0522-42af-ac4d-f50de691f4bd" finished successfully.

# %% [markdown]
# ## GCS Bucket for Terraform State:

# %%
# Create a GCS Bucket
# !gsutil mb -l {region} gs://{bucket_name}/
# Out:
# Creating gs://api-terraform-state-dev/...

# %%
# Enable Versioning
# !gsutil versioning set on gs://{bucket_name}/
# Out:
# Enabling versioning for gs://api-terraform-state-dev/...

# %% [markdown]
# ## Secrets Manager

# %%
# JWT Secret in Google Secret Manager
# !gcloud secrets create {env}-auth-jwt-secret --replication-policy="automatic"
# !echo -n {jwt_secret_value} | gcloud secrets versions add {env}-auth-jwt-secret --data-file=-
# Out:
# Created secret [dev-auth-jwt-secret].
# Created version [1] of the secret [dev-auth-jwt-secret].

# %%
# Database Credentials Secrets
# !gcloud secrets create {env}-db-username --replication-policy="automatic"
# !echo -n {db_username} | gcloud secrets versions add {env}-db-username --data-file=-

# !gcloud secrets create {env}-db-password --replication-policy="automatic"
# !echo -n {db_password} | gcloud secrets versions add {env}-db-password --data-file=-
# Out:
# Created secret [dev-db-username].
# Created version [1] of the secret [dev-db-username].
# Created secret [dev-db-password].
# Created version [1] of the secret [dev-db-password].

# %% [markdown]
# ## Terraform Deployment:
#
# Initialize and apply your Terraform configuration as usual. Include the path to `tfvars`.

# %% [markdown]
# **Initialize Terraform**

# %%
# Initialize Terraform
# !terraform init
# Out:
# Initializing the backend...
#
# Successfully configured the backend "gcs"! Terraform will automatically
# use this backend unless the backend configuration changes.
# Initializing modules...
# - artifact_registry in ../../modules/artifact_registry
# - ci_cd_service_account in ../../modules/ci_cd_service_account
# - cloud_run in ../../modules/cloud_run
# - cloud_sql in ../../modules/cloud_sql
# - load_balancer in ../../modules/load_balancer
#
# Initializing provider plugins...
# - Finding hashicorp/google versions matching "5.19.0"...
# - Installing hashicorp/google v5.19.0...
# - Installed hashicorp/google v5.19.0 (signed by HashiCorp)
#
# Terraform has created a lock file .terraform.lock.hcl to record the provider
# selections it made above. Include this file in your version control repository
# so that Terraform can guarantee to make the same selections by default when
# you run "terraform init" in the future.
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %% [markdown]
# **Apply Terraform changes**

# %% [markdown]
# Note: The following command will fail with an error because we haven't uploaded Docker image yet. `│ Error: Error waiting to create Service: resource is in failed state "Ready:False", message: Revision 'some-project-id-546757-dev-service-00001-6sm' is not ready and cannot serve traffic. Image 'us-central1-docker.pkg.dev/some-project-id-546757/some-project-id-546757-dev-repo/app-service:latest' not found.`

# %%
# Execute Terraform apply directly with hardcoded app_service_count and dynamic tfvars_file_path
# !terraform apply --auto-approve
# Out:
# Acquiring state lock. This may take a few moments...
# module.cloud_sql.data.google_secret_manager_secret_version.db_username: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_password: Reading...
# module.cloud_sql.data.google_compute_default_service_account.default: Reading...
# module.cloud_run.data.google_compute_default_service_account.default: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_password: Read complete after 1s [id=projects/812254980684/secrets/dev-db-password/versions/1]
# module.cloud_sql.data.google_secret_manager_secret_version.db_username: Read complete after 1s [id=projects/812254980684/secrets/dev-db-username/versions/1]
# module.cloud_run.data.google_compute_default_service_account.default: Read complete after 1s [id=projects/template-nestjs-api/serviceAccounts/812254980684-compute@developer.gserviceaccount.com]
# module.cloud_sql.data.google_compute_default_service_account.default: Read complete after 1s [id=projects/template-nestjs-api/serviceAccounts/812254980684-compute@developer.gserviceaccount.com]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # module.artifact_registry.google_artifact_registry_repository.docker_repository will be created
#   + resource "google_artifact_registry_repository" "docker_repository" {
#       + create_time      = (known after apply)
#       + effective_labels = (known after apply)
#       + format           = "DOCKER"
#       + id               = (known after apply)
#       + location         = "us-central1"
#       + mode             = "STANDARD_REPOSITORY"
#       + name             = (known after apply)
#       + project          = "template-nestjs-api"
#       + repository_id    = "template-nestjs-api-dev-repo"
#       + terraform_labels = (known after apply)
#       + update_time      = (known after apply)
#     }
#
#   # module.ci_cd_service_account.google_project_iam_member.cloudsql_client will be created
#   + resource "google_project_iam_member" "cloudsql_client" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "template-nestjs-api"
#       + role    = "roles/cloudsql.client"
#     }
#
#   # module.ci_cd_service_account.google_project_iam_member.editor will be created
#   + resource "google_project_iam_member" "editor" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "template-nestjs-api"
#       + role    = "roles/editor"
#     }
#
#   # module.ci_cd_service_account.google_project_iam_member.secret_manager_accessor will be created
#   + resource "google_project_iam_member" "secret_manager_accessor" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "template-nestjs-api"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.ci_cd_service_account.google_service_account.ci_cd will be created
#   + resource "google_service_account" "ci_cd" {
#       + account_id   = "dev-ci-cd-service-account"
#       + disabled     = false
#       + display_name = "dev Github action CI/CD service account"
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "template-nestjs-api"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_run.google_cloud_run_service.app_service will be created
#   + resource "google_cloud_run_service" "app_service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "template-nestjs-api-dev-service"
#       + project                    = "template-nestjs-api"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = (known after apply)
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = (known after apply)
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/template-nestjs-api/template-nestjs-api-dev-repo/dev-app-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       + name  = "API_PREFIX"
#                       + value = "api"
#                     }
#                   + env {
#                       + name  = "APP_NAME"
#                       + value = "BE Template API [dev]"
#                     }
#                   + env {
#                       + name = "AUTH_JWT_SECRET"
#
#                       + value_from {
#                           + secret_key_ref {
#                               + key  = "latest"
#                               + name = "dev-auth-jwt-secret"
#                             }
#                         }
#                     }
#                   + env {
#                       + name  = "AUTH_JWT_TOKEN_EXPIRES_IN"
#                       + value = "1d"
#                     }
#                   + env {
#                       + name  = "DATABASE_HOST"
#                       + value = (known after apply)
#                     }
#                   + env {
#                       + name  = "DATABASE_NAME"
#                       + value = "api_db"
#                     }
#                   + env {
#                       + name = "DATABASE_PASSWORD"
#
#                       + value_from {
#                           + secret_key_ref {
#                               + key  = "latest"
#                               + name = "dev-db-password"
#                             }
#                         }
#                     }
#                   + env {
#                       + name = "DATABASE_USER"
#
#                       + value_from {
#                           + secret_key_ref {
#                               + key  = "latest"
#                               + name = "dev-db-username"
#                             }
#                         }
#                     }
#                   + env {
#                       + name  = "NODE_ENV"
#                       + value = "dev"
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = jsonencode(
#             {
#               + bindings = [
#                   + {
#                       + members = [
#                           + "allUsers",
#                         ]
#                       + role    = "roles/run.invoker"
#                     },
#                 ]
#             }
#         )
#       + project     = "template-nestjs-api"
#       + service     = "template-nestjs-api-dev-service"
#     }
#
#   # module.cloud_run.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "template-nestjs-api-dev-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "template-nestjs-api"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "template-nestjs-api-dev-service"
#         }
#     }
#
#   # module.cloud_run.google_project_iam_member.secret_manager_access will be created
#   + resource "google_project_iam_member" "secret_manager_access" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = "serviceAccount:812254980684-compute@developer.gserviceaccount.com"
#       + project = "template-nestjs-api"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_sql.google_project_iam_member.cloudsql_client will be created
#   + resource "google_project_iam_member" "cloudsql_client" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = "serviceAccount:812254980684-compute@developer.gserviceaccount.com"
#       + project = "template-nestjs-api"
#       + role    = "roles/cloudsql.client"
#     }
#
#   # module.cloud_sql.google_project_iam_member.secret_manager_access will be created
#   + resource "google_project_iam_member" "secret_manager_access" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = "serviceAccount:812254980684-compute@developer.gserviceaccount.com"
#       + project = "template-nestjs-api"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_sql.google_sql_database.default will be created
#   + resource "google_sql_database" "default" {
#       + charset         = (known after apply)
#       + collation       = (known after apply)
#       + deletion_policy = "DELETE"
#       + id              = (known after apply)
#       + instance        = "template-nestjs-api-dev-db-instance"
#       + name            = "api_db"
#       + project         = "template-nestjs-api"
#       + self_link       = (known after apply)
#     }
#
#   # module.cloud_sql.google_sql_database_instance.postgres_instance will be created
#   + resource "google_sql_database_instance" "postgres_instance" {
#       + available_maintenance_versions = (known after apply)
#       + connection_name                = (known after apply)
#       + database_version               = "POSTGRES_14"
#       + deletion_protection            = false
#       + dns_name                       = (known after apply)
#       + encryption_key_name            = (known after apply)
#       + first_ip_address               = (known after apply)
#       + id                             = (known after apply)
#       + instance_type                  = (known after apply)
#       + ip_address                     = (known after apply)
#       + maintenance_version            = (known after apply)
#       + master_instance_name           = (known after apply)
#       + name                           = "template-nestjs-api-dev-db-instance"
#       + private_ip_address             = (known after apply)
#       + project                        = "template-nestjs-api"
#       + psc_service_attachment_link    = (known after apply)
#       + public_ip_address              = (known after apply)
#       + region                         = "us-central1"
#       + self_link                      = (known after apply)
#       + server_ca_cert                 = (sensitive value)
#       + service_account_email_address  = (known after apply)
#
#       + settings {
#           + activation_policy     = "ALWAYS"
#           + availability_type     = "ZONAL"
#           + connector_enforcement = (known after apply)
#           + disk_autoresize       = true
#           + disk_autoresize_limit = 0
#           + disk_size             = (known after apply)
#           + disk_type             = "PD_SSD"
#           + edition               = "ENTERPRISE"
#           + pricing_plan          = "PER_USE"
#           + tier                  = "db-f1-micro"
#           + user_labels           = (known after apply)
#           + version               = (known after apply)
#         }
#     }
#
#   # module.cloud_sql.google_sql_database_instance.postgres_replica will be created
#   + resource "google_sql_database_instance" "postgres_replica" {
#       + available_maintenance_versions = (known after apply)
#       + connection_name                = (known after apply)
#       + database_version               = "POSTGRES_14"
#       + deletion_protection            = false
#       + dns_name                       = (known after apply)
#       + encryption_key_name            = (known after apply)
#       + first_ip_address               = (known after apply)
#       + id                             = (known after apply)
#       + instance_type                  = "READ_REPLICA_INSTANCE"
#       + ip_address                     = (known after apply)
#       + maintenance_version            = (known after apply)
#       + master_instance_name           = "template-nestjs-api-dev-db-instance"
#       + name                           = "template-nestjs-api-dev-db-replica"
#       + private_ip_address             = (known after apply)
#       + project                        = "template-nestjs-api"
#       + psc_service_attachment_link    = (known after apply)
#       + public_ip_address              = (known after apply)
#       + region                         = "us-central1"
#       + self_link                      = (known after apply)
#       + server_ca_cert                 = (sensitive value)
#       + service_account_email_address  = (known after apply)
#
#       + settings {
#           + activation_policy     = "ALWAYS"
#           + availability_type     = "ZONAL"
#           + connector_enforcement = (known after apply)
#           + disk_autoresize       = true
#           + disk_autoresize_limit = 0
#           + disk_size             = (known after apply)
#           + disk_type             = "PD_SSD"
#           + edition               = "ENTERPRISE"
#           + pricing_plan          = "PER_USE"
#           + tier                  = "db-f1-micro"
#           + user_labels           = (known after apply)
#           + version               = (known after apply)
#         }
#     }
#
#   # module.cloud_sql.google_sql_user.postgres_user will be created
#   + resource "google_sql_user" "postgres_user" {
#       + host                    = (known after apply)
#       + id                      = (known after apply)
#       + instance                = "template-nestjs-api-dev-db-instance"
#       + name                    = (sensitive value)
#       + password                = (sensitive value)
#       + project                 = "template-nestjs-api"
#       + sql_server_user_details = (known after apply)
#     }
#
#   # module.load_balancer.google_compute_backend_service.cloudrun_backend_service will be created
#   + resource "google_compute_backend_service" "cloudrun_backend_service" {
#       + connection_draining_timeout_sec = 300
#       + creation_timestamp              = (known after apply)
#       + fingerprint                     = (known after apply)
#       + generated_id                    = (known after apply)
#       + id                              = (known after apply)
#       + load_balancing_scheme           = "EXTERNAL"
#       + name                            = "template-nestjs-api-dev-backend-service"
#       + port_name                       = "http"
#       + project                         = "template-nestjs-api"
#       + protocol                        = "HTTP"
#       + self_link                       = (known after apply)
#       + session_affinity                = (known after apply)
#       + timeout_sec                     = 30
#
#       + backend {
#           + balancing_mode               = "UTILIZATION"
#           + capacity_scaler              = 1
#           + group                        = (known after apply)
#           + max_connections              = (known after apply)
#           + max_connections_per_endpoint = (known after apply)
#           + max_connections_per_instance = (known after apply)
#           + max_rate                     = (known after apply)
#           + max_rate_per_endpoint        = (known after apply)
#           + max_rate_per_instance        = (known after apply)
#           + max_utilization              = (known after apply)
#         }
#     }
#
#   # module.load_balancer.google_compute_global_forwarding_rule.cloudrun_forwarding_rule will be created
#   + resource "google_compute_global_forwarding_rule" "cloudrun_forwarding_rule" {
#       + base_forwarding_rule  = (known after apply)
#       + effective_labels      = (known after apply)
#       + id                    = (known after apply)
#       + ip_address            = (known after apply)
#       + ip_protocol           = (known after apply)
#       + label_fingerprint     = (known after apply)
#       + load_balancing_scheme = "EXTERNAL"
#       + name                  = "template-nestjs-api-dev-forwarding-rule"
#       + network               = (known after apply)
#       + port_range            = "80"
#       + project               = "template-nestjs-api"
#       + psc_connection_id     = (known after apply)
#       + psc_connection_status = (known after apply)
#       + self_link             = (known after apply)
#       + subnetwork            = (known after apply)
#       + target                = (known after apply)
#       + terraform_labels      = (known after apply)
#     }
#
#   # module.load_balancer.google_compute_target_http_proxy.cloudrun_http_proxy will be created
#   + resource "google_compute_target_http_proxy" "cloudrun_http_proxy" {
#       + creation_timestamp = (known after apply)
#       + id                 = (known after apply)
#       + name               = "template-nestjs-api-dev-http-proxy"
#       + project            = "template-nestjs-api"
#       + proxy_bind         = (known after apply)
#       + proxy_id           = (known after apply)
#       + self_link          = (known after apply)
#       + url_map            = (known after apply)
#     }
#
#   # module.load_balancer.google_compute_url_map.cloudrun_url_map will be created
#   + resource "google_compute_url_map" "cloudrun_url_map" {
#       + creation_timestamp = (known after apply)
#       + default_service    = (known after apply)
#       + fingerprint        = (known after apply)
#       + id                 = (known after apply)
#       + map_id             = (known after apply)
#       + name               = "template-nestjs-api-dev-url-map"
#       + project            = "template-nestjs-api"
#       + self_link          = (known after apply)
#     }
#
# Plan: 19 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   + cloud_run_service_url = (known after apply)
#   + load_balancer_ip      = (known after apply)
# module.cloud_sql.google_project_iam_member.cloudsql_client: Creating...
# module.cloud_run.google_project_iam_member.secret_manager_access: Creating...
# module.cloud_sql.google_project_iam_member.secret_manager_access: Creating...
# module.ci_cd_service_account.google_service_account.ci_cd: Creating...
# module.artifact_registry.google_artifact_registry_repository.docker_repository: Creating...
# module.cloud_sql.google_sql_database_instance.postgres_instance: Creating...
# module.ci_cd_service_account.google_service_account.ci_cd: Creation complete after 3s [id=projects/template-nestjs-api/serviceAccounts/dev-ci-cd-service-account@template-nestjs-api.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.cloudsql_client: Creating...
# module.ci_cd_service_account.google_project_iam_member.secret_manager_accessor: Creating...
# module.ci_cd_service_account.google_project_iam_member.editor: Creating...
# module.cloud_sql.google_project_iam_member.secret_manager_access: Creation complete after 9s [id=template-nestjs-api/roles/secretmanager.secretAccessor/serviceAccount:812254980684-compute@developer.gserviceaccount.com]
# module.cloud_sql.google_project_iam_member.cloudsql_client: Still creating... [10s elapsed]
# module.cloud_run.google_project_iam_member.secret_manager_access: Still creating... [10s elapsed]
# module.artifact_registry.google_artifact_registry_repository.docker_repository: Still creating... [10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... [10s elapsed]
# module.ci_cd_service_account.google_project_iam_member.cloudsql_client: Still creating... [10s elapsed]
# module.ci_cd_service_account.google_project_iam_member.secret_manager_accessor: Still creating... [10s elapsed]
# module.ci_cd_service_account.google_project_iam_member.editor: Still creating... [10s elapsed]
# module.artifact_registry.google_artifact_registry_repository.docker_repository: Creation complete after 14s [id=projects/template-nestjs-api/locations/us-central1/repositories/template-nestjs-api-dev-repo]
# module.cloud_run.google_project_iam_member.secret_manager_access: Creation complete after 15s [id=template-nestjs-api/roles/secretmanager.secretAccessor/serviceAccount:812254980684-compute@developer.gserviceaccount.com]
# module.cloud_sql.google_project_iam_member.cloudsql_client: Creation complete after 16s [id=template-nestjs-api/roles/cloudsql.client/serviceAccount:812254980684-compute@developer.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.editor: Creation complete after 14s [id=template-nestjs-api/roles/editor/serviceAccount:dev-ci-cd-service-account@template-nestjs-api.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.secret_manager_accessor: Creation complete after 14s [id=template-nestjs-api/roles/secretmanager.secretAccessor/serviceAccount:dev-ci-cd-service-account@template-nestjs-api.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.cloudsql_client: Creation complete after 14s [id=template-nestjs-api/roles/cloudsql.client/serviceAccount:dev-ci-cd-service-account@template-nestjs-api.iam.gserviceaccount.com]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... [20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... [30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... [40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... [50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Creation complete after 11m35s [id=template-nestjs-api-dev-db-instance]
# module.cloud_sql.google_sql_database.default: Creating...
# module.cloud_sql.google_sql_user.postgres_user: Creating...
# module.cloud_sql.google_sql_database_instance.postgres_replica: Creating...
# module.cloud_run.google_cloud_run_service.app_service: Creating...
# module.cloud_sql.google_sql_database.default: Creation complete after 7s [id=projects/template-nestjs-api/instances/template-nestjs-api-dev-db-instance/databases/api_db]
# module.cloud_sql.google_sql_user.postgres_user: Still creating... [10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... [10s elapsed]
# module.cloud_run.google_cloud_run_service.app_service: Still creating... [10s elapsed]
# module.cloud_sql.google_sql_user.postgres_user: Creation complete after 15s [id=some-db-user//template-nestjs-api-dev-db-instance]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... [20s elapsed]
# module.cloud_run.google_cloud_run_service.app_service: Still creating... [20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... [30s elapsed]
# module.cloud_run.google_cloud_run_service.app_service: Still creating... [30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... [40s elapsed]
# module.cloud_run.google_cloud_run_service.app_service: Still creating... [40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... [50s elapsed]
# module.cloud_run.google_cloud_run_service.app_service: Still creating... [50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_run.google_cloud_run_service.app_service: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_run.google_cloud_run_service.app_service: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_replica: Creation complete after 13m51s [id=template-nestjs-api-dev-db-replica]
# ╷
# │ Error: Error waiting to create Service: resource is in failed state "Ready:False", message: Revision 'template-nestjs-api-dev-service-00001-8v6' is not ready and cannot serve traffic. Image 'us-central1-docker.pkg.dev/template-nestjs-api/template-nestjs-api-dev-repo/dev-app-service:latest' not found.
# │
# │   with module.cloud_run.google_cloud_run_service.app_service,
# │   on ../../modules/cloud_run/main.tf line 59, in resource "google_cloud_run_service" "app_service":
# │   59: resource "google_cloud_run_service" "app_service" {
# │
# ╵

# %% [markdown]
# ## Docker Image Build & Deployment

# %%
# !gcloud auth configure-docker
# Out:
# WARNING: Your config file at [/Users/michaljarnot/.docker/config.json] contains these credential helper entries:
#
# {
#   "credHelpers": {
#     "asia.gcr.io": "gcloud",
#     "eu.gcr.io": "gcloud",
#     "gcr.io": "gcloud",
#     "marketplace.gcr.io": "gcloud",
#     "staging-k8s.gcr.io": "gcloud",
#     "us-central1-docker.pkg.dev": "gcloud",
#     "us.gcr.io": "gcloud"
#   }
# }
# Adding credentials for all GCR repositories.
# WARNING: A long list of credential helpers may cause delays running 'docker build'. We recommend passing the registry name to configure only the registry you are using.
# gcloud credential helpers already registered correctly.

# %%
# Build the Docker image using the Dockerfile located in the parent directory.
# !docker build -t {region}-docker.pkg.dev/{project_id}/{project_id}-{env}-repo/{env}-{docker_image_name}:latest ../../../
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (2/3)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      0.2s
# [+] Building 0.3s (2/3)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      0.3s
# [+] Building 0.5s (2/3)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      0.5s
# [+] Building 0.6s (2/4)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      0.6s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
# [+] Building 0.7s (3/4)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      0.7s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
# [+] Building 0.9s (3/4)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
# [+] Building 1.0s (3/4)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.0s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
# [+] Building 1.2s (3/4)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
# [+] Building 1.2s (4/4)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
# [+] Building 1.4s (5/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 393.20kB                                      0.1s
# [+] Building 1.5s (5/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.3s
#  => => transferring context: 728.04kB                                      0.2s
# [+] Building 1.7s (5/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.34MB                                        0.4s
# [+] Building 1.9s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   0.2s
# [+] Building 2.1s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   0.3s
# [+] Building 2.2s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   0.5s
# [+] Building 2.4s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   0.6s
# [+] Building 2.5s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   0.8s
# [+] Building 2.7s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   0.9s
# [+] Building 2.8s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.1s
# [+] Building 3.0s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.2s
# [+] Building 3.1s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.4s
# [+] Building 3.3s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.5s
# [+] Building 3.4s (9/13)                                   docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
# [+] Building 3.4s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
# [+] Building 3.6s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         0.2s
# [+] Building 3.7s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         0.3s
# [+] Building 3.9s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         0.5s
# [+] Building 4.0s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         0.6s
# [+] Building 4.2s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         0.8s
# [+] Building 4.3s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         0.9s
# [+] Building 4.5s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         1.1s
# [+] Building 4.6s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         1.2s
# [+] Building 4.8s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         1.4s
# [+] Building 4.9s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         1.5s
# [+] Building 5.1s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         1.7s
# [+] Building 5.2s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         1.8s
# [+] Building 5.4s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         2.0s
# [+] Building 5.5s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         2.1s
# [+] Building 5.7s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         2.3s
# [+] Building 5.8s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         2.4s
# [+] Building 6.0s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         2.6s
# [+] Building 6.1s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         2.7s
# [+] Building 6.3s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         2.9s
# [+] Building 6.4s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         3.0s
# [+] Building 6.5s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         3.0s
#  => => # >  SWC  Running...
# [+] Building 6.6s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         3.2s
#  => => # >  SWC  Running...
# [+] Building 6.8s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
# ...
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.6s
#  => => # >  SWC  Running...
#  => => # Successfully compiled: 55 files with swc (262.06ms)
# [+] Building 8.2s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.7s
#  => => # >  SWC  Running...
#  => => # Successfully compiled: 55 files with swc (262.06ms)
# [+] Building 8.3s (10/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.9s
#  => => # >  SWC  Running...
#  => => # Successfully compiled: 55 files with swc (262.06ms)
#  => => # npm notice
#  => => # npm notice New major version of npm available! 9.5.1 -> 10.5.0
#  => => # npm
# [+] Building 8.5s (11/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.9s
#
#
#
#
#
# [+] Building 8.7s (11/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.9s
# [+] Building 8.8s (11/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.9s
# [+] Building 9.0s (11/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.9s
# [+] Building 9.1s (11/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.9s
# [+] Building 9.3s (11/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.9s
# [+] Building 9.4s (11/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.9s
# [+] Building 9.4s (12/13)                                  docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.9s
#  => CACHED [production 4/5] RUN yarn install --production                  0.0s
#  => [production 5/5] COPY --from=build /app/dist /app/dist                 0.0s
# [+] Building 9.5s (14/14) FINISHED                         docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 311B                                          0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 493B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:18-alpine3.16      1.2s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [build 1/6] FROM docker.io/library/node:18-alpine3.16@sha256:1eabdb1a  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 1.42MB                                        0.5s
#  => CACHED [build 2/6] WORKDIR /app                                        0.0s
#  => CACHED [build 3/6] COPY package*.json yarn.lock ./                     0.0s
#  => CACHED [build 4/6] RUN yarn install --production=false                 0.0s
#  => [build 5/6] COPY . .                                                   1.7s
#  => [build 6/6] RUN npx nest build                                         4.9s
#  => CACHED [production 4/5] RUN yarn install --production                  0.0s
#  => [production 5/5] COPY --from=build /app/dist /app/dist                 0.0s
#  => exporting to image                                                     0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:401a9b8074d4ee87692b7a7a8b175fe3c14d024a75961  0.0s
#  => => naming to us-central1-docker.pkg.dev/template-nestjs-api/template-  0.0s
#
# View build details: ]8;;docker-desktop://dashboard/build/desktop-linux/desktop-linux/067dqqpmvt4hkxcqbbdygk66y\docker-desktop://dashboard/build/desktop-linux/desktop-linux/067dqqpmvt4hkxcqbbdygk66y]8;;\
#
# What's Next?
#   View a summary of image vulnerabilities and recommendations → docker scout quickview

# %%
# Push Docker Image to Artifact Registry
# !docker push {region}-docker.pkg.dev/{project_id}/{project_id}-{env}-repo/{env}-{docker_image_name}:latest
# Out:
# The push refers to repository [us-central1-docker.pkg.dev/template-nestjs-api/template-nestjs-api-dev-repo/dev-app-service]
#
# 4fd2ff21: Preparing
# 927df009: Preparing
# 21e1ee48: Preparing
# a00b35e9: Preparing
# 32cce104: Preparing
# 59b2cb08: Preparing
# 6cdc78a2: Preparing
# 927df009: Pushed   1.518GB/1.475GBlatest: digest: sha256:dbae0dc8150b4b0f9569a1b6ed900ef27065b45489d268abaa24ab1aa4642795 size: 1996

# %%
# Deploy to Google Cloud Run
# !gcloud run deploy {project_id}-{env}-service --image {region}-docker.pkg.dev/{project_id}/{project_id}-{env}-repo/{env}-{docker_image_name}:latest --platform managed --region={region} --allow-unauthenticated
# Out:
# Deploying container to Cloud Run service [template-nestjs-api-dev-service] in project [template-nestjs-api] region [us-central1]
# Deploying...
#   . Creating Revision...
#   . Routing traffic...
#   . Setting IAM Policy...
#   Deploying...
#
#
#
# ⠛ Deploying...
#
#
#
# ⠹ Deploying...
#
#
#
# ⠼ Deploying...
#
#
#
# ⠶ Deploying...
#
#
#
# ⠧ Deploying...
#
#
#   ⠧ Setting IAM Policy...
# ⠏ Deploying...
#
#
#   ⠏ Setting IAM Policy...
# ⠛ Deploying...
#
#
#   ⠛ Setting IAM Policy...
# ⠹ Deploying...
#
#
#   ⠹ Setting IAM Policy...
# ⠼ Deploying...
#
#
#   ⠼ Setting IAM Policy...
# ⠶ Deploying...
#
#
#   ⠶ Setting IAM Policy...
# ⠧ Deploying...
#
#
#   ⠧ Setting IAM Policy...
# ⠏ Deploying...
#
#
#   ⠏ Setting IAM Policy...
# ⠛ Deploying...
#
#
#   ⠛ Setting IAM Policy...
# ⠹ Deploying...
#
#
#   ⠹ Setting IAM Policy...
# ⠼ Deploying...
#
#
#   ⠼ Setting IAM Policy...
# ⠶ Deploying...
#
#
#   ⠶ Setting IAM Policy...
# ⠧ Deploying...
#
#
#   ⠧ Setting IAM Policy...
# ⠏ Deploying...
#
#
#   ⠏ Setting IAM Policy...
# ⠛ Deploying...
#
#
#   ⠛ Setting IAM Policy...
# ⠹ Deploying...
#
#
#   ⠹ Setting IAM Policy...
# ⠼ Deploying...
#
#
#   ⠼ Setting IAM Policy...
# ⠶ Deploying...
#
#
#   ⠶ Setting IAM Policy...
# ⠧ Deploying...
#
#
#   ⠧ Setting IAM Policy...
# ⠏ Deploying...
#
#
#   ⠏ Setting IAM Policy...
# ⠛ Deploying...
#
#
#   ⠛ Setting IAM Policy...
# ⠹ Deploying...
#
#
#   ⠹ Setting IAM Policy...
# ⠼ Deploying...
#
#
#   ⠼ Setting IAM Policy...
# ⠶ Deploying...
#
#
#   ⠶ Setting IAM Policy...
# ⠧ Deploying...
#
#
#   ✓ Setting IAM Policy...
# ⠏ Deploying...
#   ⠏ Creating Revision...
#
#
# ⠛ Deploying...
#   ⠛ Creating Revision...
#
#
# ⠹ Deploying...
#   ⠹ Creating Revision...
#
#
# ⠼ Deploying...
#   ⠼ Creating Revision...
#
#
# ⠶ Deploying...
#   ⠶ Creating Revision...
#
#
# ⠧ Deploying...
#   ⠧ Creating Revision...
#
#
# ⠏ Deploying...
#   ⠏ Creating Revision...
#
#
# ⠛ Deploying...
#   ⠛ Creating Revision...
#
#
# ⠹ Deploying...
#   ⠹ Creating Revision...
#
#
# ⠼ Deploying...
#   ⠼ Creating Revision...
#
#
# ⠶ Deploying...
#   ⠶ Creating Revision...
#
#
# ⠧ Deploying... Deploying Revision.
#   ⠧ Creating Revision...
#
#
# ⠏ Deploying... Deploying Revision.
#   ⠏ Creating Revision...
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#   ⠛ Creating Revision...
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#   ✓ Creating Revision...
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
# ...
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying...
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying...
#
#   ✓ Routing traffic...
#
# ⠧ Deploying... Done.
#
#
#
# ⠏ Deploying... Done.
#
#
#
# ⠛ Deploying... Done.
#
#
#
# ✓ Deploying... Done.
#
#
#
# Done.
# Service [template-nestjs-api-dev-service] revision [template-nestjs-api-dev-service-00002-nar] has been deployed and is serving 100 percent of traffic.
# Service URL: https://template-nestjs-api-dev-service-3nhakjixwq-uc.a.run.app

# %% [markdown]
# ## Secrets for CI Authorization

# %%
# Define your variables
service_account_name = f"{env}-ci-cd-service-account"
service_account_email = f"{service_account_name}@{project_id}.iam.gserviceaccount.com"
key_filename = f"{env}-ci-cd-service-account-key.json"

# Construct the gcloud command
gcloud_command = f"gcloud iam service-accounts keys create ../../../{key_filename} --iam-account {service_account_email}"

# Execute the command
# !{gcloud_command}
# Out:
# created key [1af2b81d7c7fa9add606cfe5e2766dc29621cdf9] of type [json] as [../../../dev-ci-cd-service-account-key.json] for [dev-ci-cd-service-account@template-nestjs-api.iam.gserviceaccount.com]

# %% [markdown]
# ## GitHub Secrets
#
# Go to your GitHub repository and navigate to `Settings` > `Secrets`.
#
# Add a new secrets:
#
# - GCP_PROJECT_ID
# - GCP_REGION
# - GCP_{env}_SA_KEY
# - GCP_{env}_REPOSITORY
# - GCP_{env}_IMAGE_NAME

# %%
# Print secrets for GitHub
print(f"GCP_PROJECT_ID: {project_id}")
print(f"GCP_REGION: {region}")
print(f"GCP_{env.upper()}_SA_KEY: >>contents of {key_filename}<<")
print(f"GCP_{env.upper()}_REPOSITORY: {project_id}-{env}-repo")
print(f"GCP_{env.upper()}_IMAGE_NAME: {env}-{docker_image_name}")
# Out:
# GCP_PROJECT_ID: template-nestjs-api
# GCP_REGION: us-central1
# GCP_DEV_SA_KEY: >>contents of dev-ci-cd-service-account-key.json<<
# GCP_DEV_REPOSITORY: template-nestjs-api-dev-repo
# GCP_DEV_IMAGE_NAME: dev-app-service
